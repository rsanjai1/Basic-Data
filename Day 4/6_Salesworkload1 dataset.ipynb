# %% [markdown]
# # Data visualization

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Import dataset

# %%
data=pd.read_csv(r"C:\Users\user\Downloads\6_Salesworkload1.csv")

# %% [markdown]
# print data

# %%
data
# Out:
#      MonthYear  Time index         Country  StoreID        City  Dept_ID  \
# 0      10.2016         1.0  United Kingdom  88253.0  London (I)      1.0
# 1      10.2016         1.0  United Kingdom  88253.0  London (I)      2.0
# 2      10.2016         1.0  United Kingdom  88253.0  London (I)      3.0
# 3      10.2016         1.0  United Kingdom  88253.0  London (I)      4.0
# 4      10.2016         1.0  United Kingdom  88253.0  London (I)      5.0
# ...        ...         ...             ...      ...         ...      ...
# 7653   06.2017         9.0          Sweden  29650.0  Gothenburg     12.0
# 7654   06.2017         9.0          Sweden  29650.0  Gothenburg     16.0
# 7655   06.2017         9.0          Sweden  29650.0  Gothenburg     11.0
# 7656   06.2017         9.0          Sweden  29650.0  Gothenburg     17.0
# 7657   06.2017         9.0          Sweden  29650.0  Gothenburg     18.0
#
#                Dept. Name  HoursOwn  HoursLease  Sales units    Turnover  \
# ...

# %% [markdown]
# print first 10 rows using head

# %%
data.head(10)
# Out:
#   MonthYear  Time index         Country  StoreID        City  Dept_ID  \
# 0   10.2016         1.0  United Kingdom  88253.0  London (I)      1.0
# 1   10.2016         1.0  United Kingdom  88253.0  London (I)      2.0
# 2   10.2016         1.0  United Kingdom  88253.0  London (I)      3.0
# 3   10.2016         1.0  United Kingdom  88253.0  London (I)      4.0
# 4   10.2016         1.0  United Kingdom  88253.0  London (I)      5.0
# 5   10.2016         1.0  United Kingdom  88253.0  London (I)      6.0
# 6   10.2016         1.0  United Kingdom  88253.0  London (I)     13.0
# 7   10.2016         1.0  United Kingdom  88253.0  London (I)      7.0
# 8   10.2016         1.0  United Kingdom  88253.0  London (I)      8.0
# 9   10.2016         1.0  United Kingdom  88253.0  London (I)      9.0
#
#             Dept. Name   HoursOwn  HoursLease  Sales units   Turnover  \
# 0                  Dry   3184.764         0.0     398560.0  1226244.0
# ...

# %% [markdown]
# print last 10 rows using tail

# %%
data.tail(5)
# Out:
#      MonthYear  Time index Country  StoreID        City  Dept_ID  \
# 7653   06.2017         9.0  Sweden  29650.0  Gothenburg     12.0
# 7654   06.2017         9.0  Sweden  29650.0  Gothenburg     16.0
# 7655   06.2017         9.0  Sweden  29650.0  Gothenburg     11.0
# 7656   06.2017         9.0  Sweden  29650.0  Gothenburg     17.0
# 7657   06.2017         9.0  Sweden  29650.0  Gothenburg     18.0
#
#              Dept. Name  HoursOwn  HoursLease  Sales units    Turnover  \
# 7653           Checkout  6322.323         0.0    3886530.0  14538825.0
# 7654  Customer Services  4270.479         0.0        245.0         0.0
# 7655           Delivery         0         0.0          0.0         0.0
# 7656             others  2224.929         0.0        245.0         0.0
# 7657                all   39652.2         0.0    3886530.0  15056214.0
#
#       Customer Area (m2) Opening hours
# 7653       NaN       #NV        Type A
# 7654       NaN       #NV        Type A
# ...

# %% [markdown]
# print describe of dataset

# %%
data.describe()
# Out:
#         Time index       StoreID      Dept_ID   HoursLease   Sales units  \
# count  7650.000000   7650.000000  7650.000000  7650.000000  7.650000e+03
# mean      5.000000  61995.220000     9.470588    22.036078  1.076471e+06
# std       2.582158  29924.581631     5.337429   133.299513  1.728113e+06
# min       1.000000  12227.000000     1.000000     0.000000  0.000000e+00
# 25%       3.000000  29650.000000     5.000000     0.000000  5.457125e+04
# 50%       5.000000  75400.500000     9.000000     0.000000  2.932300e+05
# 75%       7.000000  87703.000000    14.000000     0.000000  9.175075e+05
# max       9.000000  98422.000000    18.000000  3984.000000  1.124296e+07
#
#            Turnover  Customer
# count  7.650000e+03       0.0
# mean   3.721393e+06       NaN
# std    6.003380e+06       NaN
# min    0.000000e+00       NaN
# 25%    2.726798e+05       NaN
# 50%    9.319575e+05       NaN
# 75%    3.264432e+06       NaN
# max    4.271739e+07       NaN

# %% [markdown]
# Number elements in dataset

# %%
data.size
# Out:
# 107212

# %% [markdown]
# print shape of dataset

# %%
data.shape
# Out:
# (7658, 14)

# %% [markdown]
# print empty or not

# %%
data.isna()
# Out:
#       MonthYear  Time index  Country  StoreID   City  Dept_ID  Dept. Name  \
# 0         False       False    False    False  False    False       False
# 1         False       False    False    False  False    False       False
# 2         False       False    False    False  False    False       False
# 3         False       False    False    False  False    False       False
# 4         False       False    False    False  False    False       False
# ...         ...         ...      ...      ...    ...      ...         ...
# 7653      False       False    False    False  False    False       False
# 7654      False       False    False    False  False    False       False
# 7655      False       False    False    False  False    False       False
# 7656      False       False    False    False  False    False       False
# 7657      False       False    False    False  False    False       False
#
#       HoursOwn  HoursLease  Sales units  Turnover  Customer  Area (m2)  \
# ...

# %%
data.isnull().sum()
# Out:
# MonthYear           0
# Time index          8
# Country             8
# StoreID             8
# City                8
# Dept_ID             8
# Dept. Name          8
# HoursOwn            8
# HoursLease          8
# Sales units         8
# Turnover            8
# Customer         7658
# Area (m2)           8
# Opening hours       8
# dtype: int64

# %%
data1 = data.fillna(value=10)
data1
# Out:
#      MonthYear  Time index         Country  StoreID        City  Dept_ID  \
# 0      10.2016         1.0  United Kingdom  88253.0  London (I)      1.0
# 1      10.2016         1.0  United Kingdom  88253.0  London (I)      2.0
# 2      10.2016         1.0  United Kingdom  88253.0  London (I)      3.0
# 3      10.2016         1.0  United Kingdom  88253.0  London (I)      4.0
# 4      10.2016         1.0  United Kingdom  88253.0  London (I)      5.0
# ...        ...         ...             ...      ...         ...      ...
# 7653   06.2017         9.0          Sweden  29650.0  Gothenburg     12.0
# 7654   06.2017         9.0          Sweden  29650.0  Gothenburg     16.0
# 7655   06.2017         9.0          Sweden  29650.0  Gothenburg     11.0
# 7656   06.2017         9.0          Sweden  29650.0  Gothenburg     17.0
# 7657   06.2017         9.0          Sweden  29650.0  Gothenburg     18.0
#
#                Dept. Name  HoursOwn  HoursLease  Sales units    Turnover  \
# ...

# %%
data1.isnull().sum()
# Out:
# MonthYear        0
# Time index       0
# Country          0
# StoreID          0
# City             0
# Dept_ID          0
# Dept. Name       0
# HoursOwn         0
# HoursLease       0
# Sales units      0
# Turnover         0
# Customer         0
# Area (m2)        0
# Opening hours    0
# dtype: int64

# %%
data1 = data[["StoreID","Turnover"]]
data1
# Out:
#       StoreID    Turnover
# 0     88253.0   1226244.0
# 1     88253.0    387810.0
# 2     88253.0    654657.0
# 3     88253.0    499434.0
# 4     88253.0    329397.0
# ...       ...         ...
# 7653  29650.0  14538825.0
# 7654  29650.0         0.0
# 7655  29650.0         0.0
# 7656  29650.0         0.0
# 7657  29650.0  15056214.0
#
# [7658 rows x 2 columns]

# %%
data1.plot.line()
# Out:
# <AxesSubplot:>

# %%
data1.plot.bar()
# Out:
# <AxesSubplot:>

# %%
data1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.plot.box('km')
# Out:
# <AxesSubplot:>

# %%
data2 = data1["Turnover"]

# %%
data2.plot.pie()
# Out:
# <AxesSubplot:ylabel='Turnover'>

# %%
data1.plot.scatter("StoreID","Turnover")
# Out:
# <AxesSubplot:xlabel='StoreID', ylabel='Turnover'>

# %%
data1.plot.area()
# Out:
# <AxesSubplot:>
