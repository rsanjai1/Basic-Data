# %% [markdown]
# # Data visualization

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Import dataset

# %%
data=pd.read_csv(r"C:\Users\user\Downloads\fiat500_VehicleSelection_Dataset(1).csv")

# %% [markdown]
# print data

# %%
data
# Out:
#        ID   model  engine_power  age_in_days        km  previous_owners  \
# 0     1.0  lounge          51.0        882.0   25000.0              1.0
# 1     2.0     pop          51.0       1186.0   32500.0              1.0
# 2     3.0   sport          74.0       4658.0  142228.0              1.0
# 3     4.0  lounge          51.0       2739.0  160000.0              1.0
# 4     5.0     pop          73.0       3074.0  106880.0              1.0
# ...   ...     ...           ...          ...       ...              ...
# 1544  NaN     NaN           NaN          NaN       NaN              NaN
# 1545  NaN     NaN           NaN          NaN       NaN              NaN
# 1546  NaN     NaN           NaN          NaN       NaN              NaN
# 1547  NaN     NaN           NaN          NaN       NaN              NaN
# 1548  NaN     NaN           NaN          NaN       NaN              NaN
#
#             lat          lon     price  Unnamed: 9 Unnamed: 10
# ...

# %% [markdown]
# print first 10 rows using head

# %%
data.head(10)
# Out:
#      ID   model  engine_power  age_in_days        km  previous_owners  \
# 0   1.0  lounge          51.0        882.0   25000.0              1.0
# 1   2.0     pop          51.0       1186.0   32500.0              1.0
# 2   3.0   sport          74.0       4658.0  142228.0              1.0
# 3   4.0  lounge          51.0       2739.0  160000.0              1.0
# 4   5.0     pop          73.0       3074.0  106880.0              1.0
# 5   6.0     pop          74.0       3623.0   70225.0              1.0
# 6   7.0  lounge          51.0        731.0   11600.0              1.0
# 7   8.0  lounge          51.0       1521.0   49076.0              1.0
# 8   9.0   sport          73.0       4049.0   76000.0              1.0
# 9  10.0   sport          51.0       3653.0   89000.0              1.0
#
#          lat          lon  price  Unnamed: 9 Unnamed: 10
# 0  44.907242  8.611559868   8900         NaN         NaN
# 1  45.666359  12.24188995   8800         NaN         NaN
# ...

# %% [markdown]
# print last 10 rows using tail

# %%
data.tail(5)
# Out:
#       ID model  engine_power  age_in_days  km  previous_owners  lat  \
# 1544 NaN   NaN           NaN          NaN NaN              NaN  NaN
# 1545 NaN   NaN           NaN          NaN NaN              NaN  NaN
# 1546 NaN   NaN           NaN          NaN NaN              NaN  NaN
# 1547 NaN   NaN           NaN          NaN NaN              NaN  NaN
# 1548 NaN   NaN           NaN          NaN NaN              NaN  NaN
#
#               lon     price  Unnamed: 9 Unnamed: 10
# 1544       length         5         NaN         NaN
# 1545       concat  lonprice         NaN         NaN
# 1546  Null values        NO         NaN         NaN
# 1547         find         1         NaN         NaN
# 1548       search         1         NaN         NaN

# %% [markdown]
# print describe of dataset

# %%
data.describe()
# Out:
#                 ID  engine_power  age_in_days             km  previous_owners  \
# count  1538.000000   1538.000000  1538.000000    1538.000000      1538.000000
# mean    769.500000     51.904421  1650.980494   53396.011704         1.123537
# std     444.126671      3.988023  1289.522278   40046.830723         0.416423
# min       1.000000     51.000000   366.000000    1232.000000         1.000000
# 25%     385.250000     51.000000   670.000000   20006.250000         1.000000
# 50%     769.500000     51.000000  1035.000000   39031.000000         1.000000
# 75%    1153.750000     51.000000  2616.000000   79667.750000         1.000000
# max    1538.000000     77.000000  4658.000000  235000.000000         4.000000
#
#                lat  Unnamed: 9
# count  1538.000000         0.0
# mean     43.541361         NaN
# std       2.133518         NaN
# min      36.855839         NaN
# 25%      41.802990         NaN
# 50%      44.394096         NaN
# 75%      45.467960         NaN
# ...

# %% [markdown]
# Number elements in dataset

# %%
data.size
# Out:
# 17039

# %% [markdown]
# print shape of dataset

# %%
data.shape
# Out:
# (1549, 11)

# %% [markdown]
# print empty or not

# %%
data.isna()
# Out:
#          ID  model  engine_power  age_in_days     km  previous_owners    lat  \
# 0     False  False         False        False  False            False  False
# 1     False  False         False        False  False            False  False
# 2     False  False         False        False  False            False  False
# 3     False  False         False        False  False            False  False
# 4     False  False         False        False  False            False  False
# ...     ...    ...           ...          ...    ...              ...    ...
# 1544   True   True          True         True   True             True   True
# 1545   True   True          True         True   True             True   True
# 1546   True   True          True         True   True             True   True
# 1547   True   True          True         True   True             True   True
# 1548   True   True          True         True   True             True   True
#
#         lon  price  Unnamed: 9  Unnamed: 10
# ...

# %%
data.isnull().sum()
# Out:
# ID                   11
# model                11
# engine_power         11
# age_in_days          11
# km                   11
# previous_owners      11
# lat                  11
# lon                   0
# price                 0
# Unnamed: 9         1549
# Unnamed: 10        1548
# dtype: int64

# %%
data1 = data.fillna(value=10)
data1
# Out:
#         ID   model  engine_power  age_in_days        km  previous_owners  \
# 0      1.0  lounge          51.0        882.0   25000.0              1.0
# 1      2.0     pop          51.0       1186.0   32500.0              1.0
# 2      3.0   sport          74.0       4658.0  142228.0              1.0
# 3      4.0  lounge          51.0       2739.0  160000.0              1.0
# 4      5.0     pop          73.0       3074.0  106880.0              1.0
# ...    ...     ...           ...          ...       ...              ...
# 1544  10.0      10          10.0         10.0      10.0             10.0
# 1545  10.0      10          10.0         10.0      10.0             10.0
# 1546  10.0      10          10.0         10.0      10.0             10.0
# 1547  10.0      10          10.0         10.0      10.0             10.0
# 1548  10.0      10          10.0         10.0      10.0             10.0
#
#             lat          lon     price  Unnamed: 9 Unnamed: 10
# ...

# %%
data1[10:20]
# Out:
#       ID   model  engine_power  age_in_days        km  previous_owners  \
# 10  11.0     pop          51.0        790.0   43286.0              1.0
# 11  12.0  lounge          51.0        366.0   17500.0              1.0
# 12  13.0  lounge          51.0        456.0   18450.0              1.0
# 13  14.0     pop          51.0       3835.0  120000.0              1.0
# 14  15.0  lounge          51.0       1035.0   40500.0              1.0
# 15  16.0  lounge          51.0       1096.0   28200.0              1.0
# 16  17.0  lounge          73.0       4200.0  110000.0              1.0
# 17  18.0     pop          51.0       2223.0   96848.0              1.0
# 18  19.0  lounge          51.0       2861.0   31000.0              1.0
# 19  20.0  lounge          51.0        425.0   20030.0              1.0
#
#           lat          lon  price  Unnamed: 9 Unnamed: 10
# 10  40.871429  14.43896008   8950        10.0          10
# 11  45.069679  7.704919815  10990        10.0          10
# ...

# %%
data[data["ID"]<=20]
# Out:
#       ID   model  engine_power  age_in_days        km  previous_owners  \
# 0    1.0  lounge          51.0        882.0   25000.0              1.0
# 1    2.0     pop          51.0       1186.0   32500.0              1.0
# 2    3.0   sport          74.0       4658.0  142228.0              1.0
# 3    4.0  lounge          51.0       2739.0  160000.0              1.0
# 4    5.0     pop          73.0       3074.0  106880.0              1.0
# 5    6.0     pop          74.0       3623.0   70225.0              1.0
# 6    7.0  lounge          51.0        731.0   11600.0              1.0
# 7    8.0  lounge          51.0       1521.0   49076.0              1.0
# 8    9.0   sport          73.0       4049.0   76000.0              1.0
# 9   10.0   sport          51.0       3653.0   89000.0              1.0
# 10  11.0     pop          51.0        790.0   43286.0              1.0
# 11  12.0  lounge          51.0        366.0   17500.0              1.0
# ...

# %%
data1["ID"]
# Out:
# 0        1.0
# 1        2.0
# 2        3.0
# 3        4.0
# 4        5.0
#         ...
# 1544    10.0
# 1545    10.0
# 1546    10.0
# 1547    10.0
# 1548    10.0
# Name: ID, Length: 1549, dtype: float64

# %%
data1["km"]
# Out:
# 0        25000.0
# 1        32500.0
# 2       142228.0
# 3       160000.0
# 4       106880.0
#           ...
# 1544        10.0
# 1545        10.0
# 1546        10.0
# 1547        10.0
# 1548        10.0
# Name: km, Length: 1549, dtype: float64

# %%
data1 = data[["engine_power","km"]]
data1
# Out:
#       engine_power        km
# 0             51.0   25000.0
# 1             51.0   32500.0
# 2             74.0  142228.0
# 3             51.0  160000.0
# 4             73.0  106880.0
# ...            ...       ...
# 1544           NaN       NaN
# 1545           NaN       NaN
# 1546           NaN       NaN
# 1547           NaN       NaN
# 1548           NaN       NaN
#
# [1549 rows x 2 columns]

# %%
data1.plot.line()
# Out:
# <AxesSubplot:>

# %%
data1.plot.bar()
# Out:
# <AxesSubplot:>

# %%
data1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.plot.box('km')
# Out:
# <AxesSubplot:>

# %%
data2 = data1["km"]

# %%
data2.plot.pie()
# Out:
# <AxesSubplot:ylabel='km'>

# %%
data1.plot.scatter('km','engine_power')
# Out:
# <AxesSubplot:xlabel='km', ylabel='engine_power'>

# %%
data1.plot.area()
# Out:
# <AxesSubplot:>
