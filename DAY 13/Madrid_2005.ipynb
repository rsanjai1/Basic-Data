# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"c:\Users\user\Downloads\csvs_per_year\madrid_2005.csv")
df
# Out:
#                        date   BEN    CO   EBE   MXY  NMHC       NO_2  \
# 0       2005-11-01 01:00:00   NaN  0.77   NaN   NaN   NaN  57.130001
# 1       2005-11-01 01:00:00  1.52  0.65  1.49  4.57  0.25  86.559998
# 2       2005-11-01 01:00:00   NaN  0.40   NaN   NaN   NaN  46.119999
# 3       2005-11-01 01:00:00   NaN  0.42   NaN   NaN   NaN  37.220001
# 4       2005-11-01 01:00:00   NaN  0.57   NaN   NaN   NaN  32.160000
# ...                     ...   ...   ...   ...   ...   ...        ...
# 236995  2006-01-01 00:00:00  1.08  0.36  1.01   NaN  0.11  21.990000
# 236996  2006-01-01 00:00:00  0.39  0.54  1.00  1.00  0.11   2.200000
# 236997  2006-01-01 00:00:00  0.19   NaN  0.26   NaN  0.08  26.730000
# 236998  2006-01-01 00:00:00  0.14   NaN  1.00   NaN  0.06  13.770000
# 236999  2006-01-01 00:00:00  0.50  0.40  0.73  1.84  0.13  20.940001
#
#                NOx   OXY        O_3   PM10   PM25   PXY   SO_2   TCH   TOL  \
# ...

# %%
df1 = df.fillna(0)
df1
# Out:
#                        date   BEN    CO   EBE   MXY  NMHC       NO_2  \
# 0       2005-11-01 01:00:00  0.00  0.77  0.00  0.00  0.00  57.130001
# 1       2005-11-01 01:00:00  1.52  0.65  1.49  4.57  0.25  86.559998
# 2       2005-11-01 01:00:00  0.00  0.40  0.00  0.00  0.00  46.119999
# 3       2005-11-01 01:00:00  0.00  0.42  0.00  0.00  0.00  37.220001
# 4       2005-11-01 01:00:00  0.00  0.57  0.00  0.00  0.00  32.160000
# ...                     ...   ...   ...   ...   ...   ...        ...
# 236995  2006-01-01 00:00:00  1.08  0.36  1.01  0.00  0.11  21.990000
# 236996  2006-01-01 00:00:00  0.39  0.54  1.00  1.00  0.11   2.200000
# 236997  2006-01-01 00:00:00  0.19  0.00  0.26  0.00  0.08  26.730000
# 236998  2006-01-01 00:00:00  0.14  0.00  1.00  0.00  0.06  13.770000
# 236999  2006-01-01 00:00:00  0.50  0.40  0.73  1.84  0.13  20.940001
#
#                NOx   OXY        O_3   PM10   PM25   PXY   SO_2   TCH   TOL  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237000 entries, 0 to 236999
# Data columns (total 17 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   date     237000 non-null  object
#  1   BEN      70370 non-null   float64
#  2   CO       217656 non-null  float64
#  3   EBE      68955 non-null   float64
#  4   MXY      32549 non-null   float64
#  5   NMHC     92854 non-null   float64
#  6   NO_2     235022 non-null  float64
#  7   NOx      235049 non-null  float64
#  8   OXY      32555 non-null   float64
#  9   O_3      223162 non-null  float64
#  10  PM10     232142 non-null  float64
#  11  PM25     69407 non-null   float64
#  12  PXY      32549 non-null   float64
#  13  SO_2     235277 non-null  float64
#  14  TCH      93076 non-null   float64
#  15  TOL      70255 non-null   float64
#  16  station  237000 non-null  int64
# dtypes: float64(15), int64(1), object(1)
# memory usage: 30.7+ MB

# %%
df.columns
# Out:
# Index(['date', 'BEN', 'CO', 'EBE', 'MXY', 'NMHC', 'NO_2', 'NOx', 'OXY', 'O_3',
#        'PM10', 'PM25', 'PXY', 'SO_2', 'TCH', 'TOL', 'station'],
#       dtype='object')

# %%
df2=df1[['BEN', 'CO', 'EBE', 'MXY', 'NMHC', 'NO_2', 'NOx', 'OXY', 'O_3',
       'PM10', 'PXY', 'SO_2', 'TCH', 'TOL', 'station']]

# %%
sns.pairplot(df2)

# %%
sns.distplot(df2['O_3'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='O_3', ylabel='Density'>

# %%
sns.heatmap(df2.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Linear Regression

# %%
x = df2[['BEN', 'CO', 'EBE', 'MXY', 'NMHC', 'NO_2', 'NOx', 'OXY',
       'PM10', 'PXY', 'SO_2', 'TCH', 'TOL']]
y = df2['O_3']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
# Out:
# 51.345382388356136

# %%
coeff=pd.DataFrame(lr.coef_,x.columns,columns=['Co-effecient'])
coeff
# Out:
#       Co-effecient
# BEN       1.659441
# CO        4.356877
# EBE      -0.079391
# MXY      -0.274476
# NMHC      7.735000
# NO_2     -0.223691
# NOx      -0.088383
# OXY       0.583711
# PM10      0.112554
# PXY       0.547173
# SO_2     -0.027498
# TCH      -2.626640
# TOL      -0.264784

# %%
prediction=lr.predict(x_test)
plt.scatter(y_test,prediction)

# %%
print(lr.score(x_test,y_test))
# Out:
# 0.29055837427924014

# %%
lr.score(x_train,y_train)
# Out:
# 0.28719339023118273

# %% [markdown]
# # Ridge Lasso

# %%
from sklearn.linear_model import Ridge,Lasso

# %%
rr=Ridge(alpha=10)
rr.fit(x_train,y_train)
rr.score(x_test,y_test)
# Out:
# 0.290561226617848

# %%
predict2=(rr.predict(x_test))

# %%
la=Lasso(alpha=10)
la.fit(x_train,y_train)
# Out:
# Lasso(alpha=10)

# %%
la.score(x_test,y_test)
# Out:
# 0.2832131061940065

# %% [markdown]
# # Elastic Net regression

# %%
from sklearn.linear_model import ElasticNet
en=ElasticNet()
en.fit(x_train,y_train)
# Out:
# ElasticNet()

# %%
print(en.coef_)
# Out:
# [ 0.00359166  0.          0.          0.14414352 -0.         -0.2377292
#  -0.06797027  0.          0.11207785  0.08179725  0.04075399 -0.3713311
#  -0.03332536]

# %%
print(en.intercept_)
# Out:
# 51.07874193422498

# %%
print(en.score(x_test,y_test))
# Out:
# 0.28525680587689206

# %%
print(en.score(x_train,y_train))
# Out:
# 0.28116514548383775

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
feature_matrix=df2.iloc[:,0:5]
target_vector=df2.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler

# %%
fs=StandardScaler().fit_transform(feature_matrix)

# %%
logr=LogisticRegression()
logr.fit(fs,target_vector)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
df2.shape
# Out:
# (237000, 15)

# %%
observation=[[1,2,3,4,5]]
predication = logr.predict(observation)

# %%
print(predication)
# Out:
# [28079099]

# %%
logr.classes_
# Out:
# array([28079001, 28079003, 28079004, 28079006, 28079007, 28079008,
#        28079009, 28079011, 28079012, 28079014, 28079015, 28079016,
#        28079017, 28079018, 28079019, 28079021, 28079022, 28079023,
#        28079024, 28079025, 28079026, 28079027, 28079035, 28079036,
#        28079038, 28079039, 28079040, 28079099], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(feature_matrix,target_vector,test_size=0.30)

# %%
print(logr.score(x_test,y_test))
# Out:
# 0.10466947960618847

# %%
print(logr.score(x_train,y_train))
# Out:
# 0.10541892706449668

# %% [markdown]
# # Conclusion

# %% [markdown]
# Linear Regression is bestfit model
#
# Linear Regression is bestfit model for dataset madrid_2001. The Score x_test,y_test is0.10466947960618847 and x_train,y_train score is 0.10541892706449668
