# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sea

# %%
d = pd.read_csv(r'C:\Users\user\Downloads\C4_framingham.csv')
d
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4233       66.0     86.0           1
# 4234       65.0     68.0           0
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# 4237       80.0    107.0           0
#
# [4238 rows x 16 columns]

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# memory usage: 529.9 KB

# %%
d['prevalentHyp'].value_counts()
# Out:
# 0    2922
# 1    1316
# Name: prevalentHyp, dtype: int64

# %%
x = d.drop('prevalentHyp',axis=1)
y=d['prevalentHyp']

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# memory usage: 529.9 KB

# %%
d.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
d1 = d[['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
       'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
       'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD']]
d1
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4233       66.0     86.0           1
# 4234       65.0     68.0           0
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# 4237       80.0    107.0           0
#
# [4238 rows x 16 columns]

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# memory usage: 529.9 KB

# %%
d2 = d.fillna(0)

# %%
x = d2[['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
       'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
       'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD']]
y = d2['prevalentHyp']

# %%
g1 = {"prevalentHyp":{'0':1,'N':2}}
d2= d2.replace(g1)
print(d2)
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     0.0
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4233       66.0     86.0           1
# 4234       65.0     68.0           0
# 4235       84.0     86.0           0
# 4236       86.0      0.0           0
# 4237       80.0    107.0           0
#
# [4238 rows x 16 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.70)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
y_train.shape
# Out:
# (2966,)

# %%
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
parameters = {
    'max_depth':[10,20,50,60,30],
    'min_samples_leaf':[35,16,75,70,45],
    'n_estimators':[10,20,30,40,50]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(estimator=rfc,param_grid=parameters,cv=2,scoring='accuracy')
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=2, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [10, 20, 50, 60, 30],
#                          'min_samples_leaf': [35, 16, 75, 70, 45],
#                          'n_estimators': [10, 20, 30, 40, 50]},
#              scoring='accuracy')

# %%
grid_search.best_score_
# Out:
# 1.0

# %%
from sklearn.tree import plot_tree

# %%
rfc_best= grid_search.best_estimator_

# %%
plt.figure(figsize=(80,60))
plot_tree(rfc_best.estimators_[5],feature_names=x.columns,class_names=["Yes","No"],filled=True)
# Out:
# [Text(3185.25, 3057.75, 'sysBP <= 139.75\ngini = 0.424\nsamples = 1877\nvalue = [2061, 905]\nclass = Yes'),
#  Text(2384.785714285714, 2650.05, 'diaBP <= 89.75\ngini = 0.154\nsamples = 1292\nvalue = [1879, 173]\nclass = Yes'),
#  Text(1846.7142857142858, 2242.35, 'heartRate <= 79.5\ngini = 0.088\nsamples = 1190\nvalue = [1808, 87]\nclass = Yes'),
#  Text(1089.4285714285716, 1834.6499999999999, 'sysBP <= 125.75\ngini = 0.064\nsamples = 794\nvalue = [1203, 41]\nclass = Yes'),
#  Text(584.5714285714286, 1426.95, 'age <= 46.5\ngini = 0.026\nsamples = 540\nvalue = [829, 11]\nclass = Yes'),
#  Text(318.8571428571429, 1019.25, 'cigsPerDay <= 10.5\ngini = 0.008\nsamples = 313\nvalue = [496, 2]\nclass = Yes'),
#  Text(212.57142857142858, 611.5500000000002, 'diaBP <= 79.75\ngini = 0.014\nsamples = 184\nvalue = [275, 2]\nclass = Yes'),
#  Text(106.28571428571429, 203.8499999999999, 'gini = 0.0\nsamples = 133\nvalue = [201, 0]\nclass = Yes'),
#  Text(318.8571428571429, 203.8499999999999, 'gini = 0.051\nsamples = 51\nvalue = [74, 2]\nclass = Yes'),
#  Text(425.14285714285717, 611.5500000000002, 'gini = 0.0\nsamples = 129\nvalue = [221, 0]\nclass = Yes'),
#  Text(850.2857142857143, 1019.25, 'sysBP <= 117.25\ngini = 0.051\nsamples = 227\nvalue = [333, 9]\nclass = Yes'),
#  Text(637.7142857142858, 611.5500000000002, 'diaBP <= 74.5\ngini = 0.011\nsamples = 122\nvalue = [184, 1]\nclass = Yes'),
#  Text(531.4285714285714, 203.8499999999999, 'gini = 0.0\nsamples = 77\nvalue = [123, 0]\nclass = Yes'),
#  Text(744.0, 203.8499999999999, 'gini = 0.032\nsamples = 45\nvalue = [61, 1]\nclass = Yes'),
#  Text(1062.857142857143, 611.5500000000002, 'totChol <= 238.5\ngini = 0.097\nsamples = 105\nvalue = [149, 8]\nclass = Yes'),
#  Text(956.5714285714287, 203.8499999999999, 'gini = 0.067\nsamples = 58\nvalue = [84, 3]\nclass = Yes'),
#  Text(1169.142857142857, 203.8499999999999, 'gini = 0.133\nsamples = 47\nvalue = [65, 5]\nclass = Yes'),
#  Text(1594.2857142857144, 1426.95, 'diaBP <= 81.5\ngini = 0.137\nsamples = 254\nvalue = [374, 30]\nclass = Yes'),
#  Text(1381.7142857142858, 1019.25, 'sysBP <= 132.75\ngini = 0.029\nsamples = 123\nvalue = [202, 3]\nclass = Yes'),
#  Text(1275.4285714285716, 611.5500000000002, 'gini = 0.0\nsamples = 83\nvalue = [141, 0]\nclass = Yes'),
#  Text(1488.0, 611.5500000000002, 'gini = 0.089\nsamples = 40\nvalue = [61, 3]\nclass = Yes'),
#  Text(1806.857142857143, 1019.25, 'totChol <= 229.0\ngini = 0.235\nsamples = 131\nvalue = [172, 27]\nclass = Yes'),
#  Text(1700.5714285714287, 611.5500000000002, 'gini = 0.092\nsamples = 53\nvalue = [79, 4]\nclass = Yes'),
#  Text(1913.1428571428573, 611.5500000000002, 'totChol <= 259.5\ngini = 0.318\nsamples = 78\nvalue = [93, 23]\nclass = Yes'),
#  Text(1806.857142857143, 203.8499999999999, 'gini = 0.379\nsamples = 37\nvalue = [44, 15]\nclass = Yes'),
#  Text(2019.4285714285716, 203.8499999999999, 'gini = 0.241\nsamples = 41\nvalue = [49, 8]\nclass = Yes'),
#  Text(2604.0, 1834.6499999999999, 'sysBP <= 122.75\ngini = 0.131\nsamples = 396\nvalue = [605, 46]\nclass = Yes'),
#  Text(2338.285714285714, 1426.95, 'sysBP <= 119.5\ngini = 0.022\nsamples = 213\nvalue = [359, 4]\nclass = Yes'),
#  Text(2232.0, 1019.25, 'totChol <= 192.5\ngini = 0.014\nsamples = 168\nvalue = [279, 2]\nclass = Yes'),
#  Text(2125.714285714286, 611.5500000000002, 'gini = 0.07\nsamples = 35\nvalue = [53, 2]\nclass = Yes'),
#  Text(2338.285714285714, 611.5500000000002, 'gini = 0.0\nsamples = 133\nvalue = [226, 0]\nclass = Yes'),
#  Text(2444.571428571429, 1019.25, 'gini = 0.048\nsamples = 45\nvalue = [80, 2]\nclass = Yes'),
#  Text(2869.714285714286, 1426.95, 'currentSmoker <= 0.5\ngini = 0.249\nsamples = 183\nvalue = [246, 42]\nclass = Yes'),
#  Text(2657.1428571428573, 1019.25, 'totChol <= 237.5\ngini = 0.325\nsamples = 85\nvalue = [113, 29]\nclass = Yes'),
#  Text(2550.857142857143, 611.5500000000002, 'gini = 0.153\nsamples = 35\nvalue = [55, 5]\nclass = Yes'),
#  Text(2763.4285714285716, 611.5500000000002, 'gini = 0.414\nsamples = 50\nvalue = [58, 24]\nclass = Yes'),
#  Text(3082.2857142857147, 1019.25, 'diaBP <= 82.75\ngini = 0.162\nsamples = 98\nvalue = [133, 13]\nclass = Yes'),
#  Text(2976.0, 611.5500000000002, 'gini = 0.102\nsamples = 50\nvalue = [70, 4]\nclass = Yes'),
#  Text(3188.571428571429, 611.5500000000002, 'gini = 0.219\nsamples = 48\nvalue = [63, 9]\nclass = Yes'),
#  Text(2922.857142857143, 2242.35, 'prevalentHyp <= 0.5\ngini = 0.495\nsamples = 102\nvalue = [71, 86]\nclass = No'),
#  Text(2816.571428571429, 1834.6499999999999, 'gini = 0.0\nsamples = 48\nvalue = [71, 0]\nclass = Yes'),
#  Text(3029.1428571428573, 1834.6499999999999, 'gini = 0.0\nsamples = 54\nvalue = [0, 86]\nclass = No'),
#  Text(3985.714285714286, 2650.05, 'diaBP <= 89.25\ngini = 0.319\nsamples = 585\nvalue = [182, 732]\nclass = No'),
#  Text(3720.0, 2242.35, 'sysBP <= 148.5\ngini = 0.449\nsamples = 203\nvalue = [105, 204]\nclass = No'),
#  Text(3507.4285714285716, 1834.6499999999999, 'glucose <= 86.5\ngini = 0.496\nsamples = 114\nvalue = [82, 99]\nclass = No'),
#  Text(3401.1428571428573, 1426.95, 'cigsPerDay <= 0.5\ngini = 0.462\nsamples = 73\nvalue = [42, 74]\nclass = No'),
#  Text(3294.857142857143, 1019.25, 'gini = 0.437\nsamples = 38\nvalue = [21, 44]\nclass = No'),
#  Text(3507.4285714285716, 1019.25, 'gini = 0.484\nsamples = 35\nvalue = [21, 30]\nclass = No'),
#  Text(3613.714285714286, 1426.95, 'gini = 0.473\nsamples = 41\nvalue = [40, 25]\nclass = Yes'),
#  Text(3932.571428571429, 1834.6499999999999, 'totChol <= 244.5\ngini = 0.295\nsamples = 89\nvalue = [23, 105]\nclass = No'),
#  Text(3826.2857142857147, 1426.95, 'gini = 0.212\nsamples = 44\nvalue = [7, 51]\nclass = No'),
#  Text(4038.857142857143, 1426.95, 'gini = 0.353\nsamples = 45\nvalue = [16, 54]\nclass = No'),
#  Text(4251.428571428572, 2242.35, 'prevalentHyp <= 0.5\ngini = 0.222\nsamples = 382\nvalue = [77, 528]\nclass = No'),
#  Text(4145.142857142858, 1834.6499999999999, 'gini = 0.0\nsamples = 47\nvalue = [77, 0]\nclass = Yes'),
#  Text(4357.714285714286, 1834.6499999999999, 'gini = 0.0\nsamples = 335\nvalue = [0, 528]\nclass = No')]
